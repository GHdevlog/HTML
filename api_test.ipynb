# %%
link = "https://api.signal.bz/news/realtime"

# %%
import requests

r = requests.get(link)

# %%
r
# Out:
# <Response [200]>

# %%
from pprint import pprint

d = r.json()

pprint(d)
# Out:
# {'articles': [{'desc': '한눈에 보는 오늘 : 사회 - 뉴스 : (사진=뉴시스 DB). *재판매 및 DB 금지 '
#                        '[인천=뉴시스] 김동영 기자 = 인천 지역 교회에서 밥을 먹다가 의식을 잃고 쓰러진 여고생이 '
#                        '학대를 당해 숨졌을 가능성이 있다는 국립과학수사연구원의 소견이 나왔다. 경찰은 여고생과 함께 지낸 '
#                        '50대 신도에...',
#                'image': 'https://news.nateimg.co.kr/orgImg/ns/2024/05/17/NISI20210421_0017372184_web.jpg',
#                'link': 'https://news.nate.com/view/20240517n23617',
#                'name': '교회서 숨진 여고생 학대 가능성',
#                'title': '교회에서 저녁 먹다 쓰러진 여고생 사망…"학대 가능성 있다"'},
#               {'desc': '한눈에 보는 오늘 : 연예가 화제 - 뉴스 : 김호중 인스타그램음주 뺑소니 의혹에 휩싸인 가수 '
#                        '김호중이 사고 전 방문한 유흥업소가 이른바 ‘텐프로’라 불리는 룸살롱으로 드러났다고 JTBC가 '
#                        '17일 보도했다.JTBC는 김호중이 찾은 유흥업소를 찾아가 이 같은 사실을 확인했다며 업소를 '
#                        '방문했다. 업소...',
#                'image': 'https://news.nateimg.co.kr/orgImg/kz/2024/05/17/news-p.v1.20240517.d45640754c8644ea8922f0f6ac54faf8_P1.jpg',
# ...

# %%
top10 = d['top10']

top10
# Out:
# [{'rank': 1, 'keyword': '푸틴 시진핑과 올림픽', 'state': 's'},
#  {'rank': 2, 'keyword': '민희진 음반 하이브', 'state': '+'},
#  {'rank': 3, 'keyword': '교회에서 학대 가능성', 'state': '-'},
#  {'rank': 4, 'keyword': '구혜선', 'state': '-'},
#  {'rank': 5, 'keyword': '보장률 65.7 로', 'state': '+'},
#  {'rank': 6, 'keyword': '윤이나 두산 16강', 'state': '-'},
#  {'rank': 7, 'keyword': '뉴진스 조명 할명수', 'state': 's'},
#  {'rank': 8, 'keyword': '파타야 살인 사건 용의자', 'state': 's'},
#  {'rank': 9, 'keyword': '생방송 투데이', 'state': 's'},
#  {'rank': 10, 'keyword': '이호진', 'state': 's'}]

# %%
[
    {
        "rank": 1,
        "keyword": "송다은 BTS 지민과",
        "state": "s"
    },
    {
        "rank": 2,
        "keyword": "HLB FDA 승인",
        "state": "s"
    },
    {
        "rank": 3,
        "keyword": "김호중",
        "state": "s"
    },
    {
        "rank": 4,
        "keyword": "파타야 살인 사건 용의자",
        "state": "s"
    },
    {
        "rank": 5,
        "keyword": "뉴진스 DITTO 6억",
        "state": "s"
    },
    {
        "rank": 6,
        "keyword": "이호진",
        "state": "s"
    },
    {
        "rank": 7,
        "keyword": "구혜선 재산 노숙",
        "state": "s"
    },
    {
        "rank": 8,
        "keyword": "우원식",
        "state": "s"
    },
    {
        "rank": 9,
        "keyword": "국민연금공단",
        "state": "s"
    },
    {
        "rank": 10,
        "keyword": "민희진 의결권 가처분",
        "state": "s"
    }
]
# Out:
# [{'rank': 1, 'keyword': '송다은 BTS 지민과', 'state': 's'},
#  {'rank': 2, 'keyword': 'HLB FDA 승인', 'state': 's'},
#  {'rank': 3, 'keyword': '김호중', 'state': 's'},
#  {'rank': 4, 'keyword': '파타야 살인 사건 용의자', 'state': 's'},
#  {'rank': 5, 'keyword': '뉴진스 DITTO 6억', 'state': 's'},
#  {'rank': 6, 'keyword': '이호진', 'state': 's'},
#  {'rank': 7, 'keyword': '구혜선 재산 노숙', 'state': 's'},
#  {'rank': 8, 'keyword': '우원식', 'state': 's'},
#  {'rank': 9, 'keyword': '국민연금공단', 'state': 's'},
#  {'rank': 10, 'keyword': '민희진 의결권 가처분', 'state': 's'}]
